# %%
import imaplib

# %%
imaplib.IMAP4_SSL('imap.gmail.com')
# Out:
# ---------------------------------------------------------------------------
# BlockingIOError                           Traceback (most recent call last)
# c:\Users\Dell\Desktop\Let-Me-Study-Classes\Python-Courses\Python-Classes-Philips\Email\Overview-of-recieving-email.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/Let-Me-Study-Classes/Python-Courses/Python-Classes-Philips/Email/Overview-of-recieving-email.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> imaplib.IMAP4_SSL('imap.gmail.com')
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\imaplib.py:1323, in IMAP4_SSL.__init__(self, host, port, keyfile, certfile, ssl_context, timeout)
#    1320     ssl_context = ssl._create_stdlib_context(certfile=certfile,
#    1321                                              keyfile=keyfile)
#    1322 self.ssl_context = ssl_context
# -> 1323 IMAP4.__init__(self, host, port, timeout)
#
# ...

# %%
M = imaplib.IMAP4_SSL('imap.gmail.com')

# %%
import getpass

# %%
userEmail = input('Enter your email :')

# %%
userPass = getpass.getpass("Enter your Password :")

# %%
M.login(userEmail, userPass)
# Out:
# ('OK', [b'somtechie22@gmail.com authenticated (Success)'])

# %%
M.list()
# Out:
# ('OK',
#  [b'(\\HasNoChildren) "/" "Clutter"',
#   b'(\\HasNoChildren) "/" "Deloitte"',
#   b'(\\HasNoChildren) "/" "INBOX"',
#   b'(\\HasChildren \\Noselect) "/" "[Gmail]"',
#   b'(\\All \\HasNoChildren) "/" "[Gmail]/All Mail"',
#   b'(\\HasNoChildren \\Trash) "/" "[Gmail]/Bin"',
#   b'(\\Drafts \\HasNoChildren) "/" "[Gmail]/Drafts"',
#   b'(\\HasNoChildren \\Important) "/" "[Gmail]/Important"',
#   b'(\\HasNoChildren \\Sent) "/" "[Gmail]/Sent Mail"',
#   b'(\\HasNoChildren \\Junk) "/" "[Gmail]/Spam"',
#   b'(\\Flagged \\HasNoChildren) "/" "[Gmail]/Starred"'])

# %%
M.select("inbox")
# Out:
# ('OK', [b'34460'])

# %%
typ, data = M.search(None, 'SUBJECT "Security alert"')

# %%
data
# Out:
# [b'2 18 20 36 61 86 106 159 180 266 320 437 438 452 674 733 741 1346 1678 1837 2344 2772 3154 4443 4548 4582 4630 5686 7617 7850 7923 10452 11075 11913 11915 12902 13203 13212 13302 14424 15227 15228 17848 17862 17903 17905 18037 18038 18490 19201 19202 19235 19879 19900 19901 19972 20412 20414 21163 21176 23135 24371 24911 24915 25281 25282 25294 25509 26412 26909 28089 28191 28464 28513 29713 29848 31186 31196 31228 31231 31235 31693 31695 31726 31786 31787 33405 33531 33535 34116 34117 34122 34138 34341 34460']

# %%
import email
for num in data[0].split():
    type, emailData = M.fetch(num, "(RFC822)")
    raw_email = emailData[0][1]
    raw_email_string = raw_email.decode('utf-8')
    emailMessage = email.message_from_string(raw_email_string)
    for part in emailMessage.walk():
        if(part.get_content_type() == 'text/plain'):
            body = part.get_payload(decode=True)
            print(body)
# Out:
# b"Somendra Tiwari\r\n\r\nRecovery phone was changed\r\nsomtechie22@gmail.com\r\nThe recovery phone for your account was changed. If you didn't change it,\r\nyou should check what happened.\r\n\r\n\r\n\r\nCheck activity\r\n<https://accounts.google.com/AccountChooser?Email=somtechie22@gmail.com&continue=https://myaccount.google.com/device-activity/nt/1534116667363?rfn%3D4%26rfnc%3D1%26eid%3D8611695802521352176%26et%3D0%26asae%3D2>\r\n<https://accounts.google.com/AccountChooser?Email=somtechie22@gmail.com&continue=https://myaccount.google.com/device-activity/nt/1534116667363?rfn%3D4%26rfnc%3D1%26eid%3D8611695802521352176%26et%3D0%26asae%3D2>\r\n\r\n\r\nYou received this email to let you know about important changes to your\r\nGoogle Account and services.\r\n\xc2\xa9 2018 Google LLC,1600 Amphitheatre Parkway, Mountain View, CA 94043, USA\r\n1534116667363169\r\n"
# ...
